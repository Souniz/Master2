# %%
import numba.cuda
import numpy as np
import math

my_gpu = numba.cuda.get_current_device()

print(f'Running on GPU: {my_gpu.name}')

cc = my_gpu.compute_capability
print(f'Compute capability: {cc}') 
print(f'Number of streaming multiprocess: {my_gpu.MULTIPROCESSOR_COUNT}')


xDim = my_gpu.MAX_BLOCK_DIM_X
yDim = my_gpu.MAX_BLOCK_DIM_Y
zDim = my_gpu.MAX_BLOCK_DIM_Z
print(f'Max dimension size of a thread block (x, y, z): ({xDim}, {yDim}, {zDim})')
print(f'Maximum number of threads per block: {my_gpu.MAX_THREADS_PER_BLOCK}')
xGrid = my_gpu.MAX_GRID_DIM_X
yGrid = my_gpu.MAX_GRID_DIM_X
zGrid = my_gpu.MAX_GRID_DIM_Z
print(f'Max dimension size of a block grid (x, y, z): ({xGrid}, {yGrid}, {zGrid})')
print(f'Warp Size: {my_gpu.WARP_SIZE}')
